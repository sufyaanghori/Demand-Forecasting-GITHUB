# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
computed_insights_df = pd.read_csv('C:\\Users\\sufya\\OneDrive\\Desktop\\Demand Forecasting\\Sales of summer clothes in E-cmmerce Wish\\computed_insight_success_of_active_sellers.csv')
product_ratings_df = pd.read_csv('C:\\Users\\sufya\\OneDrive\\Desktop\\Demand Forecasting\\Sales of summer clothes in E-cmmerce Wish\\summer-products-with-rating-and-performance_2020-08.csv')
unique_categories_df = pd.read_csv('C:\\Users\\sufya\\OneDrive\\Desktop\\Demand Forecasting\\Sales of summer clothes in E-cmmerce Wish\\unique-categories.csv')
categories_count_df = pd.read_csv('C:\\Users\\sufya\\OneDrive\\Desktop\\Demand Forecasting\\Sales of summer clothes in E-cmmerce Wish\\unique-categories.sorted-by-count.csv')

# %%
computed_insights_df.head(10)
# Out:
#                  merchantid  listedproducts  totalunitssold  \
# 0  5357bcf2bb72c5504882e889               2          120000
# 1  5708773c3c02161b3f8c7900               5          107100
# 2  5417aada4ad3ab27e954b76c               2          100007
# 3  570f3a713a698c14278bb51e               1          100000
# 4  53082ea15aefb07dfe1f2a4f               1          100000
# 5  53f2beb39020ee03566d6e18               1          100000
# 6  5926c5ace8ff5525241b368d               7           96000
# 7  5860c757b1e41d4d67d183e8               4           90100
# 8  52bd3ddb34067e4620a4c62d               3           80000
# 9  5a7b23a69bda4e3d375e7b3f               5           80000
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 0                  60000.0   4.219              320031.0               9.00
# 1                  21420.0   3.934              139223.0               7.76
# ...

# %%
product_ratings_df.head(1)
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
#
#    rating_five_count  ...  merchant_rating_count  merchant_rating  \
# 0               26.0  ...                    568         4.128521
#
#                 merchant_id  merchant_has_profile_picture  \
# 0  595097d6a26f6e070cb878d1                             0
#
#    merchant_profile_picture                                      product_url  \
# 0                       NaN  https://www.wish.com/c/5e9ae51d43d6a96e303acdb0
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/5e9ae...
#
# ...

# %%
# list of columns of product_ratings_df
product_ratings_df.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
unique_categories_df.head(10)
# Out:
#                   tag
# 0    #fashion #shorts
# 1    #fashion #tshirt
# 2          #Sport Bra
# 3     #Summer Clothes
# 4          #top #crop
# 5  2 piece dress sets
# 6    2 Piece Swimsuit
# 7        2014menshort
# 8  2014summermenshort
# 9         2018fashion

# %%
categories_count_df.head(10)
# Out:
#    count          keyword
# 0   1321           Summer
# 1   1315  Women's Fashion
# 2   1082          Fashion
# 3    961            Women
# 4    905           Casual
# 5    636        Plus Size
# 6    580       sleeveless
# 7    549            Dress
# 8    540           Shorts
# 9    507             Tops

# %%
# create a new dataframe from the product_ratings_df with only: product_id, title, units_sold, rating
df_wish = product_ratings_df[['product_id', 'title', 'units_sold', 'rating']]

# %%
df_wish.head(10)
# Out:
#                  product_id  \
# 0  5e9ae51d43d6a96e303acdb0
# 1  58940d436a0d3d5da4e95a38
# 2  5ea10e2c617580260d55310a
# 3  5cedf17ad1d44c52c59e4aca
# 4  5ebf5819ebac372b070b0e70
# 5  5ec645bafd107a02279c8c54
# 6  5c63a337d5e2ce4bbb3152cf
# 7  5e0ae5ebc2efb76ccf0a3391
# 8  5e6f1fb7fe4a5bb4b8bf36e5
# 9  5ccfaf238a8d535cec2dfb47
#
#                                                title  units_sold  rating
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...         100    3.76
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...       20000    3.45
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...         100    3.57
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...        5000    4.03
# 4  Femmes Shorts d'été à lacets taille élastique ...         100    3.10
# 5  Plus la taille d'été femmes décontracté sans m...          10    5.00
# 6  Women Fashion Loose Lace Blouse Blouse V Neck ...       50000    3.84
# ...

# %%
# print length of df_wish
print(len(product_ratings_df))
# Out:
# 1573

# %%
# save this dataframe into a csv file
df_wish.to_csv('C:\\Users\\sufya\\OneDrive\\Desktop\\Demand Forecasting\\Sales of summer clothes in E-cmmerce Wish\\final_Wish_dataset.csv', index=False)
